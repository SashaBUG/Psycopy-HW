# %%
import pandas as pd

# %%
import seaborn as sns

# %%
data = pd.read_csv('Sasha_stroop_pup_2022_Feb_21_1450.csv', comment='#', sep=';', header=0)
data
# Out:
#        word   color  congruent corrAns  trials.thisRepN  trials.thisTrialN  \
# 0       NaN     NaN        NaN     NaN              NaN                NaN
# 1     green   green        1.0       g              0.0                0.0
# 2     green     red        0.0       r              0.0                1.0
# 3      blue   green        0.0       g              0.0                2.0
# 4      blue     red        0.0       r              0.0                3.0
# ..      ...     ...        ...     ...              ...                ...
# 156  yellow   green        0.0       g              9.0               11.0
# 157  yellow  yellow        1.0       y              9.0               12.0
# 158   green   green        1.0       g              9.0               13.0
# 159     red     red        1.0       r              9.0               14.0
# 160  yellow    blue        0.0       b              9.0               15.0
#
# ...

# %%
data.drop(columns=['Unnamed: 20', 'frameRate', 'expName', 'date', 'psychopyVersion', 'session', 'participant'])
# Out:
#        word   color  congruent corrAns  trials.thisRepN  trials.thisTrialN  \
# 0       NaN     NaN        NaN     NaN              NaN                NaN
# 1     green   green        1.0       g              0.0                0.0
# 2     green     red        0.0       r              0.0                1.0
# 3      blue   green        0.0       g              0.0                2.0
# 4      blue     red        0.0       r              0.0                3.0
# ..      ...     ...        ...     ...              ...                ...
# 156  yellow   green        0.0       g              9.0               11.0
# 157  yellow  yellow        1.0       y              9.0               12.0
# 158   green   green        1.0       g              9.0               13.0
# 159     red     red        1.0       r              9.0               14.0
# 160  yellow    blue        0.0       b              9.0               15.0
#
# ...

# %%
sns.histplot(data=data, x="delta T", hue="congruent", bins=15)
# Out:
# <AxesSubplot:xlabel='delta T', ylabel='Count'>
